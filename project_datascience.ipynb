# %% [markdown]
# **DATASCIENCE PROJECT**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import chardet

path = '/content/drive/MyDrive/dataset/Sample - Superstore.csv'

# Detect the encoding
with open(path, 'rb') as f:
    result = chardet.detect(f.read())
    encoding = result['encoding']
    print(f"Detected encoding: {encoding}")

# Read the file with the detected encoding
df = pd.read_csv(path, encoding=encoding)
df
# Out:
# Detected encoding: Windows-1252
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 1          2  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 2          3  CA-2016-138688   12-06-16  16-06-16    Second Class    DV-13045
# 3          4  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# 4          5  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2014-110422   21-01-14  23-01-14    Second Class    TB-21400
# 9990    9991  CA-2017-121258   26-02-17  03-03-17  Standard Class    DB-13060
# 9991    9992  CA-2017-121258   26-02-17  03-03-17  Standard Class    DB-13060
# 9992    9993  CA-2017-121258   26-02-17  03-03-17  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   04-05-17  09-05-17    Second Class    CC-12220
#
# ...

# %%
df.head(10)
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688   12-06-16  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# 5       6  CA-2014-115812   09-06-14  14-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812   09-06-14  14-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812   09-06-14  14-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812   09-06-14  14-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812   09-06-14  14-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# ...

# %% [markdown]
# **CASE STUDEY 1 :SuperStore Salses Analysis**

# %% [markdown]
# > OBJECTIVES
#
#
# *   what is the overall sales trend?
# *   sales by category
#
# *   sales by sub category
#
# *   profit analysis
#
# *   profit analysis by customer segments
# *   which are the top 10 prducts by sales
#
#
# *   which are the most selling products
# *   which is the most preferred ship mode
#
#
#
#
# *   which is the most profitable category and subcategory
#
#
# *   List item

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import plotly.colors as colors

# %%
df.describe()  #simple without round function
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.shape
# Out:
# (9994, 21)

# %%
#HOW MANY COLUMNS INSIDE THE DATAFRAME

df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# CONCISE SUMMARY OF THE DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.memory_usage()  #how many memory usage of each columns
# Out:
# Index              128
# Row ID           79952
# Order ID         79952
# Order Date       79952
# Ship Date        79952
# Ship Mode        79952
# Customer ID      79952
# Customer Name    79952
# Segment          79952
# Country          79952
# City             79952
# State            79952
# Postal Code      79952
# Region           79952
# Product ID       79952
# Category         79952
# Sub-Category     79952
# Product Name     79952
# Sales            79952
# Quantity         79952
# Discount         79952
# Profit           79952
# dtype: int64

# %%
# checking missing value
df.isna().sum()  #it has not any null values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# generating descriptve stastistics summary
df.describe().round()
# Out:
#        Row ID  Postal Code    Sales  Quantity  Discount  Profit
# count  9994.0       9994.0   9994.0    9994.0    9994.0  9994.0
# mean   4998.0      55190.0    230.0       4.0       0.0    29.0
# std    2885.0      32064.0    623.0       2.0       0.0   234.0
# min       1.0       1040.0      0.0       1.0       0.0 -6600.0
# 25%    2499.0      23223.0     17.0       2.0       0.0     2.0
# 50%    4998.0      56430.0     54.0       3.0       0.0     9.0
# 75%    7496.0      90008.0    210.0       5.0       0.0    29.0
# max    9994.0      99301.0  22638.0      14.0       1.0  8400.0

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# **what is the overall sales trend?**

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156   08-11-16  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688   12-06-16  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966   11-10-15  18-10-15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# first i convert this date column into datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])
# Out:
# <ipython-input-15-2a04d19b8c78>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# getting month year from the order date
df['Month_year'] =df['Order Date'].apply(lambda x :x.strftime("%Y-%m"))

# %%
df['Month_year']
# Out:
# 0       2016-08
# 1       2016-08
# 2       2016-12
# 3       2015-11
# 4       2015-11
#          ...
# 9989    2014-01
# 9990    2017-02
# 9991    2017-02
# 9992    2017-02
# 9993    2017-04
# Name: Month_year, Length: 9994, dtype: object

# %%
print(df['Month_year'].unique())
print(df['Month_year'].dtype)
# Out:
# ['2016-08' '2016-12' '2015-11' '2014-09' '2017-04' '2016-05' '2014-11'
#  '2014-05' '2014-08' '2016-09' '2017-07' '2015-09' '2016-01' '2017-10'
#  '2015-12' '2016-07' '2017-09' '2016-11' '2014-10' '2016-06' '2015-04'
#  '2016-04' '2014-12' '2015-03' '2017-11' '2017-05' '2015-01' '2017-06'
#  '2015-10' '2017-12' '2016-03' '2015-02' '2015-05' '2017-02' '2016-10'
#  '2015-07' '2014-01' '2014-03' '2017-03' '2017-01' '2017-08' '2014-04'
#  '2015-06' '2014-07' '2014-06' '2015-08' '2014-02' '2016-02']
# object

# %%
# now group by 'month_year', and 'sales' of sum
df_temp = df.groupby('Month_year')['Sales'].sum().reset_index()

# %%
df_temp
# Out:
#    Month_year       Sales
# 0     2014-01  28953.7060
# 1     2014-02  12743.1080
# 2     2014-03  54801.9060
# 3     2014-04  24710.0160
# 4     2014-05  29639.8340
# 5     2014-06  29287.0306
# 6     2014-07  35341.2460
# 7     2014-08  37854.5475
# 8     2014-09  66110.2238
# 9     2014-10  34561.9470
# 10    2014-11  64817.6185
# 11    2014-12  65426.3147
# 12    2015-01  29347.3864
# 13    2015-02  20728.3520
# 14    2015-03  40876.6112
# 15    2015-04  38056.9685
# 16    2015-05  30933.7145
# 17    2015-06  28862.1982
# 18    2015-07  28730.3760
# 19    2015-08  50094.5280
# 20    2015-09  66729.3290
# 21    2015-10  32025.0750
# 22    2015-11  50732.3090
# 23    2015-12  53415.6612
# 24    2016-01  38048.1840
# 25    2016-02  49238.4100
# 26    2016-03  49612.0450
# 27    2016-04  45192.2780
# 28    2016-05  64964.3218
# 29    2016-06  38991.9430
# 30    2016-07  42773.3950
# 31    2016-08  46339.9884
# 32    2016-09  41985.1423
# 33    2016-10  52268.1500
# ...

# %%
df_temp.max()
# Out:
# Month_year     2017-12
# Sales         89306.24
# dtype: object

# %%
#see the plot for this data
plt.figure(figsize=(16,5))
plt.plot(df_temp['Month_year'],df_temp['Sales'],color='#b80045')
plt.xticks(rotation ='vertical',size=8)
plt.xlabel('month_year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# highest sales in the month of november 2017

# %%
# if we want to clear plot the graph like bar plot
plt.figure(figsize=(16,5))
plt.bar(df_temp['Month_year'],df_temp['Sales'],color='#b80045')
plt.xticks(rotation ='vertical',size=8)
plt.xlabel('month_year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # SALES BY CATEGORY

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Month_year'],
#       dtype='object')

# %%
# group by according to sales and category
sales_by_category =df.groupby('Category')['Sales'].sum().reset_index()

# %%
sales_by_category.sum()
# Out:
# Category    FurnitureOffice SuppliesTechnology
# Sales                             2297200.8603
# dtype: object

# %%
sales_by_category
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
fig =px.pie(sales_by_category,values='Sales',names='Category')
fig.update_layout(title_text ='sales analysis by category')
fig.update_traces(textposition='inside',textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# TECHNOLOGY HAS HIGHEST SALES APPROX(36.4%) WITH BLUE COLORS

# %%
sales_by_subcategory = df.groupby('Sub-Category')['Sales'].sum().reset_index()

# %%
sales_by_subcategory
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27118.7920
# 3       Binders  203412.7330
# 4     Bookcases  114879.9963
# 5        Chairs  328449.1030
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91705.1640
# 10       Labels   12486.3120
# 11     Machines  189238.6310
# 12        Paper   78479.2060
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320

# %%
fig = px.pie(sales_by_subcategory,values ='Sales',names='Sub-Category')
fig.update_traces(textposition='outside',textinfo= 'percent+label')
fig.update_layout(title_text ='sales analysis by subcategory')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_remp = df.groupby('Sub-Category')['Sales'].sum()

# %%
df_remp
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
df_remp.max()
# Out:
# 330007.054

# %% [markdown]
# (330007.054) PHONES HAS HIGHEST SALES AMOUNT::

# %%
df.max()  #all values those in column has contain maximum stages
# Out:
# Row ID                                         9994
# Order ID                             US-2017-169551
# Order Date                      2017-12-30 00:00:00
# Ship Date                                  31-12-17
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                           Yuma
# State                                       Wyoming
# Postal Code                                   99301
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                      22638.48
# ...

# %% [markdown]
# MONTHLY PROFIT

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df['Month_year'] =pd.to_datetime(df['Month_year'])

# %%
df['Month'] = df['Month_year'].apply(lambda x:x.strftime("%m"))  #make a month column from the 'month_year' columns

# %%
df['Month']
# Out:
# 0       08
# 1       08
# 2       12
# 3       11
# 4       11
#         ..
# 9989    01
# 9990    02
# 9991    02
# 9992    02
# 9993    04
# Name: Month, Length: 9994, dtype: object

# %%
profit_by_month  =df.groupby('Month')['Profit'].sum().reset_index()

# %%
fig = px.line(profit_by_month,x='Month',y ='Profit',title ='monthly profit analysis')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # profit by categories

# %%
profit_by_categories =df.groupby('Category')['Profit'].sum().reset_index()

# %%
fig = px.pie(profit_by_categories,values='Profit',names='Category')
fig.update_traces(textposition='outside',textinfo= 'percent+label')
fig.update_layout(title_text ='profit analysis by category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
profit_by_categories
# Out:
#           Category       Profit
# 0        Furniture   18451.2728
# 1  Office Supplies  122490.8008
# 2       Technology  145454.9481

# %% [markdown]
# MAXIMUM PROFIT  **Technology	145454.9481**

# %%
profit_by_subcategories =df.groupby('Sub-Category')['Profit'].sum().reset_index()

# %%
profit_by_subcategories
# Out:
#    Sub-Category      Profit
# 0   Accessories  41936.6357
# 1    Appliances  18138.0054
# 2           Art   6527.7870
# 3       Binders  30221.7633
# 4     Bookcases  -3472.5560
# 5        Chairs  26590.1663
# 6       Copiers  55617.8249
# 7     Envelopes   6964.1767
# 8     Fasteners    949.5182
# 9   Furnishings  13059.1436
# 10       Labels   5546.2540
# 11     Machines   3384.7569
# 12        Paper  34053.5693
# 13       Phones  44515.7306
# 14      Storage  21278.8264
# 15     Supplies  -1189.0995
# 16       Tables -17725.4811

# %%
df_profit = df.groupby('Sub-Category')['Profit'].sum().reset_index()

# %%
plt.bar(df_profit['Sub-Category'],df_profit['Profit'],color='red')
plt.xticks(rotation='vertical')
plt.xlabel('sub-categories')
plt.ylabel('profit')
plt.show()

# %% [markdown]
# COPIERS HAS HIGHEST PROFIT

# %% [markdown]
# # PROFIT ANALYSIS BY CUSTOMER SEGMENTS

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# PROFIT ANALYSIS BY CUSTOMER SEGMENTS

# %%
sales_profit_segment = df.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()

# %%
sales_profit_segment
# Out:
#        Segment         Sales       Profit
# 0     Consumer  1.161401e+06  134119.2092
# 1    Corporate  7.061464e+05   91979.1340
# 2  Home Office  4.296531e+05   60298.6785

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=sales_profit_segment['Segment'],
                     y =sales_profit_segment['Sales'],
                     name ='Sales'
                     ))
fig.add_trace(go.Bar(x=sales_profit_segment['Segment'],
                     y =sales_profit_segment['Profit'],
                     name ='Profit'
                     ))

fig.update_layout(title ='sales and profit analysis by customer segement',
                  xaxis_title ='customer_segment',yaxis_title='amount')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# sales by profit ratio

# %%
sales_profit_segment['sales_by_profit_ratio'] = sales_profit_segment['Sales']/sales_profit_segment['Profit']

# %%
sales_profit_segment[['sales_by_profit_ratio','Segment']]  #HIGHER SALES RATIO PROFIT IN CONSUMER FIELD
# Out:
#    sales_by_profit_ratio      Segment
# 0               8.659471     Consumer
# 1               7.677245    Corporate
# 2               7.125416  Home Office

# %% [markdown]
# # WHICH ARE THE TOP 10 PRODUCT BY SALES

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
prod_sales= pd.DataFrame(df.groupby('Product Name')['Sales'].sum())
prod_sales.sort_values(by=['Sales'],inplace =True,ascending=False)

# %%
prod_sales[:10] #starting 10 values from the datafraem
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479
# GBC Ibimaster 500 Manual ProClick Binding System    19024.500
# Hewlett Packard LaserJet 3310 Copier                18839.686
# HP Designjet T520 Inkjet Large Format Printer -...  18374.895
# GBC DocuBind P400 Electric Binding System           17965.068
# High Speed Automatic Electric Letter Opener         17030.312

# %% [markdown]
# Canon imageCLASS 2200 Advanced Copier  has top product according to sales amount in the dataset

# %% [markdown]
# # which are the top selling product

# %%
best_selling_prod= pd.DataFrame(df.groupby('Product Name')['Quantity'].sum())
best_selling_prod.sort_values(by=['Quantity'],inplace =True,ascending=False)

# %%
best_selling_prod[:10] #first top 10 valeus in this case
# Out:
#                                                     Quantity
# Product Name
# Staples                                                  215
# Staple envelope                                          170
# Easy-staple paper                                        150
# Staples in misc. colors                                   86
# KI Adjustable-Height Table                                74
# Avery Non-Stick Binders                                   71
# Storex Dura Pro Binders                                   71
# GBC Premium Transparent Covers with Diagonal Li...        67
# Situations Contoured Folding Chairs, 4/Set                64
# Staple-based wall hangings                                62

# %% [markdown]
# STAPLE HAS HIGHEST SELLING RATE IN THE DATASET OR PRODUCT

# %% [markdown]
# # what is the most preferred ship mode

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
# plt.figure(figsize=(10,8))
sns.countplot(x='Ship Mode',data = df)
plt.show()

# %%
#STANDARD CLASS IS MOST PREFERRED SHIP MODE

# %% [markdown]
# # TO analyze the answer business question about the 12 months worth of sales data/

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11  11-11-16    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06  16-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10  18-10-15  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
df.loc[df['Profit']==df['Profit'].max()]  # this is the highest profit product
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 6826    6827  CA-2016-118689 2016-02-10  09-10-16  Standard Class    TC-20980
#
#      Customer Name    Segment        Country       City  ...       Product ID  \
# 6826  Tamara Chand  Corporate  United States  Lafayette  ...  TEC-CO-10004722
#
#         Category Sub-Category                           Product Name  \
# 6826  Technology      Copiers  Canon imageCLASS 2200 Advanced Copier
#
#          Sales Quantity Discount    Profit  Month_year  Month
# 6826  17499.95        5      0.0  8399.976  2016-02-01     02
#
# [1 rows x 23 columns]

# %%
import pandas as pd
import chardet

path = '/content/drive/MyDrive/datagroup/merged_sales_data.csv'

# Detect the encoding
with open(path, 'rb') as f:
    result = chardet.detect(f.read())
    encoding = result['encoding']

    print(f"Detected encoding: {encoding}")
# Out:
# Detected encoding: ascii

# %%
all_data = pd.read_csv(path,encoding=encoding)

# %%
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
# DROP ROWS OF NAN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 264       NaN     NaN              NaN        NaN        NaN              NaN
# 648       NaN     NaN              NaN        NaN        NaN              NaN
# 680       NaN     NaN              NaN        NaN        NaN              NaN
# 1385      NaN     NaN              NaN        NaN        NaN              NaN
# 1495      NaN     NaN              NaN        NaN        NaN              NaN

# %%
all_data = all_data.dropna()
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
all_data.isna() # then it shows not any null values in the datframe
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1          False    False             False       False       False
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
all_data.shape
# Out:
# (186305, 6)

# %%
all_data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
all_data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 186845    False
# 186846    False
# 186847    False
# 186848    False
# 186849    False
# Length: 186305, dtype: bool

# %%
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
# all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
# all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %%
# Check for non-numeric characters
non_numeric_values = all_data['Quantity Ordered'].str.contains('[^0-9.]')

# Print the number of non-numeric values
print(non_numeric_values.sum())

# If there are non-numeric values, you will need to clean the data
# Out:
# 355

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
# all_data['Month'] = all_data['Month'].astype('int32').
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %%
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].str.strip()  # Remove leading/trailing spaces
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'], errors='coerce')  # Convert to numeric
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].fillna(0)  # Optionally fill NaN with 0 or another value

# %%
all_data.tail()
# Out:
#        Order ID                 Product  Quantity Ordered Price Each  \
# 186845   222905  AAA Batteries (4-pack)               1.0       2.99
# 186846   222906        27in FHD Monitor               1.0     149.99
# 186847   222907    USB-C Charging Cable               1.0      11.95
# 186848   222908    USB-C Charging Cable               1.0      11.95
# 186849   222909  AAA Batteries (4-pack)               1.0       2.99
#
#             Order Date                       Purchase Address Month  \
# 186845  06/07/19 19:02          795 Pine St, Boston, MA 02215    06
# 186846  06/01/19 19:29  495 North St, New York City, NY 10001    06
# 186847  06/22/19 18:57  319 Ridge St, San Francisco, CA 94016    06
# 186848  06/26/19 18:35   916 Main St, San Francisco, CA 94016    06
# 186849  06/25/19 14:33         209 11th St, Atlanta, GA 30301    06
#
#                   City
# 186845          Boston
# 186846   New York City
# 186847   San Francisco
# 186848   San Francisco
# ...

# %%
# ADD CITY COLUMN /

# %%
all_data['City'] =all_data['Purchase Address'].str.split(",").str[1]

# %%
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month            City
# 0  136 Church St, New York City, NY 10001    12   New York City
# 1     562 2nd St, New York City, NY 10001    12   New York City
# 2    277 Main St, New York City, NY 10001    12   New York City
# 3     410 6th St, San Francisco, CA 94016    12   San Francisco
# 4           43 Hill St, Atlanta, GA 30301    12         Atlanta

# %%
all_data['Price Each'] = all_data['Price Each'].str.strip()  # Remove leading/trailing spaces
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'], errors='coerce')  # Convert to numeric
all_data['Price Each'] = all_data['Price Each'].fillna(0)  # Optionally fill NaN with 0 or another value

# %% [markdown]
# QUESTION PART FOR THE SECOND STAGE

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int32')*all_data['Price Each'].astype('float')  # multiply the (quantity ordered* price each)

# %%
all_data['Price Each'].dtype
# Out:
# dtype('float64')

# %%
all_data.head(3)
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
#
#        Order Date                        Purchase Address Month  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12
#
#              City    Sales
# 0   New York City  1700.00
# 1   New York City   600.00
# 2   New York City    11.95

# %%
# PERFORM THE CALCULATION(monthly sales)
month_sales =all_data.groupby('Month').agg({'Quantity Ordered': 'sum', 'Price Each': 'sum','Sales':'sum'})
month_sales.sort_values(by='Sales',ascending=False)
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 12              28114.0  4588415.41  4613443.34
# 10              22703.0  3715554.83  3736726.88
# 04              20558.0  3367671.02  3390670.24
# 11              19798.0  3180600.68  3199603.20
# 05              18667.0  3135125.13  3152606.75
# 03              17005.0  2791207.83  2807100.38
# 07              16072.0  2632539.56  2647775.76
# 06              15253.0  2562025.61  2577802.26
# 08              13448.0  2230345.42  2244467.88
# 02              13449.0  2188884.72  2202022.42
# 09              13109.0  2084992.09  2097560.13
# 01              10903.0  1811768.38  1822256.73
# Or                  0.0        0.00        0.00

# %%
import seaborn.objects as so
months = range(1,14)  # range of months
plt.bar(months,all_data.groupby('Month')['Sales'].sum()) # x=months range(1,14) and y = 'month' with sales groupby values
plt.xticks(months)
plt.xlabel('months')
plt.ylabel('sales in usd in $')
plt.title('monthly sales')
plt.show()

# %% [markdown]
# 12 th month has highest sales of (4613443.34 $)

# %%
# GROUP BY ACCORDING TO CITY

city_sales =all_data.groupby('City').agg({'Quantity Ordered': 'sum', 'Price Each': 'sum','Sales':'sum'})

city_sales
# Out:
#                 Quantity Ordered  Price Each       Sales
# City
#  Atlanta                 16602.0  2779908.20  2795498.58
#  Austin                  11153.0  1809873.61  1819581.75
#  Boston                  22528.0  3637409.77  3661642.01
#  Dallas                  16730.0  2752627.82  2767975.40
#  Los Angeles             33289.0  5421435.23  5452570.80
#  New York City           27932.0  4635370.83  4664317.43
#  Portland                14053.0  2307747.47  2320490.61
#  San Francisco           50239.0  8211461.74  8262203.91
#  Seattle                 16553.0  2733296.01  2747755.48

# %%
#how to make the graph of the city and theri sales
plt.bar(city_sales.index,city_sales['Sales'])
plt.xticks(rotation='vertical')
plt.xlabel('city')
plt.ylabel('sales in usd $')
plt.show()

# %%
# San Francisco	50239.0	8211461.74	8262203.91

# SANFRANCISCO HAS HIGHEST SALES RATE GIVEN ABOUVE THIS GRAPH

# %%
all_data['Order Date'].dtype
# Out:
# dtype('O')

# %%
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].str.strip()  # Remove leading/trailing spaces
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'], errors='coerce')  # Convert to numeric
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].fillna(0)

# %%
all_data['Order Date'] = pd.to_numeric(all_data['Order Date'],errors='coerce')
# all_data['Order Date'] =all_data['Order Date'].strip()
# all_data['Order Date'] = all_data['Order Date'].fillna(0)

# %%
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour

# %%
all_data.tail()
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 186845   222905  AAA Batteries (4-pack)               1.0        2.99
# 186846   222906        27in FHD Monitor               1.0      149.99
# 186847   222907    USB-C Charging Cable               1.0       11.95
# 186848   222908    USB-C Charging Cable               1.0       11.95
# 186849   222909  AAA Batteries (4-pack)               1.0        2.99
#
#         Order Date                       Purchase Address Month  \
# 186845         0.0          795 Pine St, Boston, MA 02215    06
# 186846         0.0  495 North St, New York City, NY 10001    06
# 186847         0.0  319 Ridge St, San Francisco, CA 94016    06
# 186848         0.0   916 Main St, San Francisco, CA 94016    06
# 186849         0.0         209 11th St, Atlanta, GA 30301    06
#
#                   City   Sales  Hour
# 186845          Boston    2.99     0
# 186846   New York City  149.99     0
# 186847   San Francisco   11.95     0
# ...

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  Order Date  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00         0.0
# 1   295666    LG Washing Machine               1.0      600.00         0.0
# 2   295667  USB-C Charging Cable               1.0       11.95         0.0
# 3   295668      27in FHD Monitor               1.0      149.99         0.0
# 4   295669  USB-C Charging Cable               1.0       11.95         0.0
#
#                          Purchase Address Month            City    Sales  Hour
# 0  136 Church St, New York City, NY 10001    12   New York City  1700.00     0
# 1     562 2nd St, New York City, NY 10001    12   New York City   600.00     0
# 2    277 Main St, New York City, NY 10001    12   New York City    11.95     0
# 3     410 6th St, San Francisco, CA 94016    12   San Francisco   149.99     0
# 4           43 Hill St, Atlanta, GA 30301    12         Atlanta    11.95     0

# %%
all_data = all_data.drop('Order Date',axis=1)

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop               1.0     1700.00
# 1   295666    LG Washing Machine               1.0      600.00
# 2   295667  USB-C Charging Cable               1.0       11.95
# 3   295668      27in FHD Monitor               1.0      149.99
# 4   295669  USB-C Charging Cable               1.0       11.95
#
#                          Purchase Address Month            City    Sales  Hour
# 0  136 Church St, New York City, NY 10001    12   New York City  1700.00     0
# 1     562 2nd St, New York City, NY 10001    12   New York City   600.00     0
# 2    277 Main St, New York City, NY 10001    12   New York City    11.95     0
# 3     410 6th St, San Francisco, CA 94016    12   San Francisco   149.99     0
# 4           43 Hill St, Atlanta, GA 30301    12         Atlanta    11.95     0

# %%
# what products are most often sold together
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 16       295681                Google Phone               1.0      600.00
# 17       295681        USB-C Charging Cable               1.0       11.95
# 18       295681  Bose SoundSport Headphones               1.0       99.99
# 19       295681            Wired Headphones               1.0       11.99
# 36       295698             Vareebadd Phone               1.0      400.00
# ...         ...                         ...               ...         ...
# 186820   222882       AA Batteries (4-pack)               1.0        3.84
# 186822   222884                Google Phone               1.0      600.00
# 186823   222884        USB-C Charging Cable               1.0       11.95
# 186842   222903                      iPhone               1.0      700.00
# 186843   222903    Lightning Charging Cable               1.0       14.95
#
#                                Purchase Address Month            City   Sales  \
# ...

# %%
df['Gruped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

df2 = df[['Order ID','Gruped']].drop_duplicates()
# Out:
# <ipython-input-173-b25772019233>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from itertools import combinations
from collections import Counter

count = Counter()
for row in df2['Gruped']:
  row_list = row.split(',')
  count.update(Counter(combinations(row_list,2)))


for key,value in count.most_common(10):
  print(key,value)
# Out:
# ('Product', 'Product') 62835
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143

# %% [markdown]
# THE MOST OFTEN PRODUCT IS iPhone', 'Lightning Charging Cable') 1005 TRANSACTIONS

# %%
# WHAT PRODUCT SOLD THE MOST

# %%
product_grouped =all_data.groupby('Product')
quantity_ordered=  product_grouped.sum()['Quantity Ordered']

keys = [pair for pair,df in product_grouped]
plt.bar(keys,quantity_ordered)
plt.xticks(keys,rotation='vertical')
plt.show()
